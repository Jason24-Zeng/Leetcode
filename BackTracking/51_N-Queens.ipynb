# %% [markdown]
# The n-queens puzzle is the problem of placing n queens on an n×n chessboard such that no two queens attack each other.
#
# The n-queens puzzle is the problem of placing n queens on an n×n chessboard such that no two queens attack each other.
#
# ![image.png](attachment:image.png)
#
# Given an integer n, return all distinct solutions to the n-queens puzzle.
#
# Each solution contains a distinct board configuration of the n-queens' placement, where 'Q' and '.' both indicate a queen and an empty space respectively.
#
# Example:
# ```python
# Input: 4
# Output: [
#  [".Q..",  // Solution 1
#   "...Q",
#   "Q...",
#   "..Q."],
#
#  ["..Q.",  // Solution 2
#   "Q...",
#   "...Q",
#   ".Q.."]
# ]
# Explanation: There exist two distinct solutions to the 4-queens puzzle as shown above.
#  ```

# %%
class Solution:
    def solveNQueens(self, n: int):
        cols, hill_diagonals, dale_diagonals = [0] * n, [0] * (2*n-1), [0] * (2*n - 1)
        queen = set()
        
        all_ans = []
        def backtrack(row = 0):
            #nonlocal result, queen, all_ans, cols, hill_diagonals, dale_diagonals
            for col in range(n):
                if (cols[col] == 0 and hill_diagonals[row-col] == 0 and dale_diagonals[row+col] == 0):
                    cols[col] = 1
                    hill_diagonals[row-col] = 1
                    dale_diagonals[row+col] = 1
                    queen.add((row, col))
                    if row + 1 == n:
                        result = []
                        for _, col in sorted(queen):
                            result.append('.' * col + 'Q' + '.'*(n-col-1))
                        all_ans.append(result)
                    else:
                        backtrack(row + 1)
                    cols[col] = 0
                    hill_diagonals[row-col] = 0
                    dale_diagonals[row+col] = 0
                    queen.remove((row, col))
        backtrack()
        return all_ans

# %%
if __name__ == '__main__':
    solution = Solution()
    ans = solution.solveNQueens(8)
    for i in ans:
        print(i)
# Out:
# ['Q.......', '....Q...', '.......Q', '.....Q..', '..Q.....', '......Q.', '.Q......', '...Q....']
# ['Q.......', '.....Q..', '.......Q', '..Q.....', '......Q.', '...Q....', '.Q......', '....Q...']
# ['Q.......', '......Q.', '...Q....', '.....Q..', '.......Q', '.Q......', '....Q...', '..Q.....']
# ['Q.......', '......Q.', '....Q...', '.......Q', '.Q......', '...Q....', '.....Q..', '..Q.....']
# ['.Q......', '...Q....', '.....Q..', '.......Q', '..Q.....', 'Q.......', '......Q.', '....Q...']
# ['.Q......', '....Q...', '......Q.', 'Q.......', '..Q.....', '.......Q', '.....Q..', '...Q....']
# ['.Q......', '....Q...', '......Q.', '...Q....', 'Q.......', '.......Q', '.....Q..', '..Q.....']
# ['.Q......', '.....Q..', 'Q.......', '......Q.', '...Q....', '.......Q', '..Q.....', '....Q...']
# ['.Q......', '.....Q..', '.......Q', '..Q.....', 'Q.......', '...Q....', '......Q.', '....Q...']
# ['.Q......', '......Q.', '..Q.....', '.....Q..', '.......Q', '....Q...', 'Q.......', '...Q....']
# ...
