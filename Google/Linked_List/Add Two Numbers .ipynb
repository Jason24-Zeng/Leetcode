# %% [markdown]
# You are given two non-empty linked lists representing two non-negative integers. The digits are stored in reverse order, and each of their nodes contains a single digit. Add the two numbers and return the sum as a linked list.
#
# You may assume the two numbers do not contain any leading zero, except the number 0 itself.
#
#
#
# Example 1:
# ```python
#
# Input: l1 = [2,4,3], l2 = [5,6,4]
# Output: [7,0,8]
# Explanation: 342 + 465 = 807.
# ```
# Example 2:
# ```python
# Input: l1 = [0], l2 = [0]
# Output: [0]
# ```
# Example 3:
# ```python
# Input: l1 = [9,9,9,9,9,9,9], l2 = [9,9,9,9]
# Output: [8,9,9,9,0,0,0,1]
# ```

# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def addTwoNumbers(self, l1: ListNode, l2: ListNode) -> ListNode:
        addition = 0
        
        if not l1:
            l1, l2 = l2, l1
        head = l1
        while l1 and l2:
            addition, l1.val = divmod(l1.val + l2.val + addition, 10)
            if not l1.next:
                if not l2.next and addition!= 0:
                    l1.next = ListNode(addition)
                    return head
                l1.next, l2.next = l2.next, None
            l1 = l1.next
            l2 = l2.next
        while l1:
            addition, l1.val = divmod(l1.val + addition, 10)
            if not l1.next:
                if addition != 0:
                    l1.next = ListNode(addition)
                return head                    
            l1 = l1.next
        
        return head

# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def addTwoNumbers(self, l1: ListNode, l2: ListNode) -> ListNode:
        addition = 0
        if not l1:
            l1, l2 = l2, l1
        head = l1
        while l1 and l2:            
            addition, l1.val = divmod(l1.val + l2.val + addition, 10)
            if not l1.next and not l2.next:
                if addition != 0:
                    l1.next = ListNode(addition)
                return head
            elif not l1.next:
                l1.next, l2.next = l2.next, None
            l1 = l1.next
            l2 = l2.next
        while l1:
            addition, l1.val = divmod(l1.val + addition, 10)
            if not l1.next:
                if addition != 0:
                    l1.next = ListNode(addition)
                return head
            
            l1 = l1.next
        
        return head

# %%
# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, val=0, next=None):
#         self.val = val
#         self.next = next
class Solution:
    def addTwoNumbers(self, l1: ListNode, l2: ListNode) -> ListNode:
        addition = 0
        if not l1:
            l1, l2 = l2, l1
        head = l1
        while l1 and l2:            
            addition, l1.val = divmod(l1.val + l2.val + addition, 10)
            if not l1.next and not l2.next:
                if addition != 0:
                    l1.next = ListNode(addition)
                return head
            elif not l1.next:
                l1.next = ListNode()
            elif not l2.next:
                l2.next = ListNode()
            l1 = l1.next
            l2 = l2.next
